# %% [markdown]
# <a href="https://colab.research.google.com/github/lLuizSales/Imersao_Dados_com_Python/blob/main/Imers%C3%A3o_dados_com_Python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 - Análise de Dados com Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("Linhas: ", linhas)
print("Colunas: ", colunas)
# Out:
# Linhas:  133349
# Colunas:  11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
renomear_coluna = {
    'work_year' : 'ano',
    'experience_level' :  'senioridade',
    'employment_type' : 'contrato',
    'job_title' : 'cargo',
    'salary' : 'salario',
    'salary_currency' : 'moeda',
    'salary_in_usd' : 'usd',
    'employee_residence' : 'residencia',
    'remote_ratio' : 'remoto',
    'company_location' : 'empresa',
    'company_size' : 'tamanho_empresa'
}

df.rename(columns = renomear_coluna, inplace = True)
df.columns
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
senioridade = {
    'SE' : 'Senior',
    'MI' : 'Pleno',
    'EN' : 'Junior',
    'EX' : 'Executivo'
}

df['senioridade'] = df['senioridade'].replace(senioridade)
df['senioridade'].value_counts()
# Out:
# senioridade
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
contrato = {
    'FT' : 'Tempo Integral',
    'PT' : 'Tempo Parcial',
    'FL' : 'Freelancer',
    'CT' : 'Contrato'
}

df['contrato'] = df['contrato'].replace(contrato)
df['contrato'].value_counts()
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'M' : 'Media',
    'L' : 'Grande',
    'S' : 'Pequena'
}

df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# Media      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
remoto = {
    0 : 'Presencial',
    100 : 'Remoto',
    50 : 'Hibrido'
}

df['remoto'] = df['remoto'].replace(remoto)
df['remoto'].value_counts()
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Hibrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Media
# 1  136000         US      Remoto      US           Media
# 2  158800         AU  Presencial      AU           Media
# 3  139200         AU  Presencial      AU           Media
# 4   90000         US  Presencial      US           Media

# %%
df.describe(include = 'object')
# Out:
#        senioridade        contrato           cargo   moeda residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Senior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Media
# freq        105312  119641          129561

# %%
df.describe()
# Out:
#                  ano       salario            usd
# count  133339.000000  1.333490e+05  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098
# std         0.680627  2.173860e+05   74288.363097
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060200e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %% [markdown]
# # Aula 2 - Preparação e Limpeza de Dados

# %%
df.isnull()
#checa informações nulas
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.isnull().sum()
#checou todo a tabela e soma todos linhas com valor null
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
#Me dá os valores únicos dentro de uma coluna, no caso a coluna 'ano'
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade        contrato                      cargo  salario  \
# 5588    NaN      Senior  Tempo Integral            Product Manager   184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Junior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Senior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Senior  Tempo Integral                   Engineer   112000
# 131000  NaN      Senior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Senior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Junior  Tempo Integral             Data Scientist    40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %%
#aprendendo a manipular uma tabela com dados nulls, preencedos eles com media ou mediana
import numpy as np

df_salarios = pd.DataFrame({
    'Nomes' : ['Luiz', 'Yuri', 'Miguel', 'Elane',  'Maria'],
    'Salário' : [10000, np.nan, 4800, np.nan, 100000]
})

df_salarios['salario_media'] = df_salarios['Salário'].fillna(df_salarios['Salário'].mean().round(2))
df_salarios
#mean() = media round(2) = arredonda
#cria uma coluna e calcula a media salarial

df_salarios['salario_mediana'] = df_salarios['Salário'].fillna(df_salarios['Salário'].median())
df_salarios
#cria uma coluna e calcula a mediana dos salrios
# Out:
#     Nomes   Salário  salario_media  salario_mediana
# 0    Luiz   10000.0       10000.00          10000.0
# 1    Yuri       NaN       38266.67          10000.0
# 2  Miguel    4800.0        4800.00           4800.0
# 3   Elane       NaN       38266.67          10000.0
# 4   Maria  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
    'Dia' : ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta'],
    'Temperatura' : [29, np.nan, np.nan, 27, 30]
})

df_temperaturas['preenchido_ffill'] = df_temperaturas['Temperatura'].ffill()
df_temperaturas
#ffill() preenche com o valor anterior
# Out:
#        Dia  Temperatura  preenchido_ffill
# 0  Segunda         29.0              29.0
# 1    Terça          NaN              29.0
# 2   Quarta          NaN              29.0
# 3   Quinta         27.0              27.0
# 4    Sexta         30.0              30.0

# %%
df_temperaturas = pd.DataFrame({
    'Dia' : ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta'],
    'Temperatura' : [29, np.nan, np.nan, 27, 30]
})

df_temperaturas['preenchido_bfill'] = df_temperaturas['Temperatura'].bfill()
df_temperaturas
#ffill() preenche com o valor posterior
# Out:
#        Dia  Temperatura  preenchido_bfill
# 0  Segunda         29.0              29.0
# 1    Terça          NaN              27.0
# 2   Quarta          NaN              27.0
# 3   Quinta         27.0              27.0
# 4    Sexta         30.0              30.0

# %%
df_cidades = pd.DataFrame({
    'Nome' : ['Luiz', 'Yuri', 'Miguel', 'Elane',  'Maria'],
    'Cidade' : ['Ceilandia', np.nan, 'Taguatinga', np.nan, 'Planaltina']
})

df_cidades['cidade_preenchida'] = df_cidades['Cidade'].fillna('Nao informado')
df_cidades
# Out:
#      Nome      Cidade cidade_preenchida
# 0    Luiz   Ceilandia         Ceilandia
# 1    Yuri         NaN     Nao informado
# 2  Miguel  Taguatinga        Taguatinga
# 3   Elane         NaN     Nao informado
# 4   Maria  Planaltina        Planaltina

# %%
df_limpo = df.dropna()
#exclui linhas com informações null

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Media
# 1  136000         US      Remoto      US           Media
# 2  158800         AU  Presencial      AU           Media
# 3  139200         AU  Presencial      AU           Media
# 4   90000         US  Presencial      US           Media

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  int64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 12.2+ MB

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Media
# 1  136000         US      Remoto      US           Media
# 2  158800         AU  Presencial      AU           Media
# 3  139200         AU  Presencial      AU           Media
# 4   90000         US  Presencial      US           Media

# %% [markdown]
# # Aula 3 - Visualização dos Dados
#
# Aprendendo a criar gráficos estatísticos para explorar e comunicar informações presente nos dados. Histogrammas, boxplots, barras, etc..

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Media
# 1  136000         US      Remoto      US           Media
# 2  158800         AU  Presencial      AU           Media
# 3  139200         AU  Presencial      AU           Media
# 4   90000         US  Presencial      US           Media

# %%
df_limpo['senioridade'].value_counts().plot(kind = 'bar', title = 'Distribuição de Senioridade')
# Out:
# <Axes: title={'center': 'Distribuição de Senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data = df_limpo, x = 'senioridade', y = 'usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = df_limpo, x = 'senioridade', y = 'usd')
plt.title('Salário médio por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual (USD)')
plt.show()

# %%
df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending = False)
# Out:
# senioridade
# Executivo    202027.667813
# Senior       172850.838301
# Pleno        143044.845979
# Junior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending = True).index
ordem
# Out:
# Index(['Junior', 'Pleno', 'Senior', 'Executivo'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(5,5))
sns.barplot(data = df_limpo, x = 'senioridade', y = 'usd', order = ordem)
plt.title('Salário médio por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual (USD)')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.histplot(df_limpo['usd'], bins = 50, kde = True)
plt.title('Distribuição dos salários anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = df_limpo['usd'])
plt.title('')
plt.xlabel('Salário USD')
plt.show()

# %%
ordem_senioridade = {'Junior', 'Pleno', 'Senior', 'Executivo'}
plt.figure(figsize = (8,5))
sns.boxplot(x = 'senioridade', y = 'usd', data = df_limpo, order = ordem_senioridade)
plt.title('Média Salárial Anual por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário Anual(USD)')
plt.show()

# %%
ordem_senioridade = {'Junior', 'Pleno', 'Senior', 'Executivo'}
plt.figure(figsize = (8,5))
sns.boxplot(x = 'senioridade', y = 'usd', data = df_limpo, order = ordem_senioridade, palette = 'Set2', hue = 'senioridade')
plt.title('Média Salárial Anual por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário Anual(USD)')
plt.show()

# %%
import plotly.express as px

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending = True).reset_index()

fig = px.bar(ordem,
             x = 'senioridade',
             y = 'usd',
             title = 'Média Salarial Anual por Senioridade',
             labels = {'senioridade' : 'Nível de Senioridade', 'usd' : 'Média Salaria Anual(USD)'}
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie( remoto_contagem,
    names = 'tipo_trabalho',
    values = 'quantidade',
    title = 'Proporção dos tipos do de trabalho'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
tamanho_empresa_contagem = df_limpo['tamanho_empresa'].value_counts().reset_index()
tamanho_empresa_contagem.columns = ['Tamanho da empresa', 'Quantidade']

fig = px.pie(tamanho_empresa_contagem,
             names = 'Tamanho da empresa',
             values = 'Quantidade',
             title = 'Quantidade de empresa por tamanho')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#salario por pais na vaga cientista de dados

top_10_paises = df_limpo['residencia'].value_counts().head(10).index.tolist()
# Identifica os 10 países com mais entradas no DataFrame e armazena seus nomes em uma lista.
df_top_10_paises = df_limpo[df_limpo['residencia'].isin(top_10_paises)]
# Um novo DataFrame contendo apenas as linhas dos 10 países mais frequentes.
df_Data_Scientist = df_top_10_paises[df_top_10_paises['cargo'] == 'Data Scientist']
# Filtra ainda mais o DataFrame para incluir apenas as linhas onde o 'cargo' é 'Data Scientist'.

media_data_scientist = df_Data_Scientist.groupby('residencia')['usd'].mean().sort_values(ascending = True).reset_index()
# Calcula a média salarial em USD ('usd') para Cientistas de Dados em cada um dos 10 países selecionados, ordena os resultados em ordem crescente e os transforma em um DataFrame.

fig = px.bar(media_data_scientist,
             x = 'residencia',
             y = 'usd',
             title = 'Vaga Cientista de Dados: Média Salárial por País',
             labels = {'residencia' : 'País', 'usd' : 'Salário Anual(USD)'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.to_csv('df_limpo.csv', index = False)

# %%
pip install pycountry

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.to_csv('df_limpo_final.csv', index=False)
